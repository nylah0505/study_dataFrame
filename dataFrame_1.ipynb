# %%
import os
import pandas as pd

# %%
os.listdir('./drive/MyDrive/machine_learning_study/machine_learning_data')
# Out:
# ['friend.csv',
#  'new_friend_index_true.csv',
#  'Naver_opinion.txt',
#  'test_csv.txt',
#  'crawlings__210510.log',
#  'wc_result1.png',
#  'wc_result.png',
#  'dolphine.jpg',
#  'abalone.data',
#  'NanumBarunGothic.ttf',
#  'new_friend.csv']

# %%
#데이터 폴더 src 변수 할당
base_src='./drive/MyDrive/machine_learning_study/machine_learning_data'

#friend.src 파일 src 변수 할당
friend_src= base_src+'/friend.csv'

# %%
# pandas의 read_csv => 데이터 불러오기
df = pd.read_csv(friend_src,encoding = 'utf-8')

# %%
# head() 데이터를 읽어주기 => 5개만 읽기
df.head()
# Out:
#     name  age        job
# 0   John   20    student
# 1  Jenny   30  developer
# 2   Nate   30    teacher
# 3  Julia   40    dentist
# 4  Brian   45    manager

# %%
new_friend_src = base_src + "/new_friend.csv"

# %%
new_friend_src
# Out:
# './drive/MyDrive/machine_learning_study/machine_learning_data/new_friend.csv'

# %%
df.to_csv('./drive/MyDrive/machine_learning_study/machine_learning_data/new_friend.csv', index=False, encoding='utf-8')

# %%
os.listdir(base_src)
# Out:
# ['friend.csv',
#  'new_friend_index_true.csv',
#  'Naver_opinion.txt',
#  'test_csv.txt',
#  'crawlings__210510.log',
#  'wc_result1.png',
#  'wc_result.png',
#  'dolphine.jpg',
#  'abalone.data',
#  'NanumBarunGothic.ttf',
#  'new_friend.csv']

# %%
#인덱스 사용 이유: 조회, 데이터 정렬

# %%
#series 실습
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
pd.Series([1,2,3], index=['가','나','다'])
# Out:
# 가    1
# 나    2
# 다    3
# dtype: int64

# %%
#데이터 프레임(집합) => 시리즈 (단일) => 데이터프레임
series=df['name']
series
# Out:
# 0     John
# 1    Jenny
# 2     Nate
# 3    Julia
# 4    Brian
# 5    Chris
# Name: name, dtype: object

# %%
#pd.Series 함수를 통해서 만드는 것도 가능
series = pd.Series([1,2,3,4])
series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#pd.Series의 옵션이 무엇이 있는지 확인
#index => 할당값의 지정 이름, 중복가능 ['a','a','b','c']
#dtype => 대표적 int, float, string, boolean 등

series = pd.Series ( [1,2,3,4] , index=['a','b','c','d'], dtype=float)
series
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    4.0
# dtype: float64

# %%
series = pd.Series([10,2,5,4], index=['a','b','c','d'],dtype=float)
series.sort_values(ascending=True)
# Out:
# b     2.0
# d     4.0
# c     5.0
# a    10.0
# dtype: float64

# %%
series.sort_values(ascending=False)
# Out:
# a    10.0
# c     5.0
# d     4.0
# b     2.0
# dtype: float64

# %%
# DataFrame 실습
df= pd.DataFrame({'a':[2,3], 'b':[5,10],'z':[2,3], 'd':[5,10],'w':[2,3], 'h':[5,10]})
df
# Out:
#    a   b  z   d  w   h
# 0  2   5  2   5  2   5
# 1  3  10  3  10  3  10
